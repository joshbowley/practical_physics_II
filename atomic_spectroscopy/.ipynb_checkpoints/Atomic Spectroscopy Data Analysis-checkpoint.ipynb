# %% [markdown]
# # Atomic Spectroscopy Data Analysis
#
# Data analysis of atomic spectroscopy data of the Balmer Series of Hydrogen to obtain a value for the Rydberg Constant.

# %% [markdown]
# ## 1. Calibrating the diffraction grating
#
# The diffraction grating has a listed grating constant $g$ of 600. We are using data from neon to confirm that this is the case.
